# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import pandas as pd
import glob
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.patches import Path, PathPatch
import numpy as np
from numba import jit
import matplotlib.mlab as ml
from mpl_toolkits.mplot3d import Axes3D

# %%
df = pd.read_csv("man_TO_wu16.csv")

# %%
for i in range(14,20):
    df16 = df[df.lat==i]
    plt.figure()
    plt.scatter(df16.lon,-df16.depth)
    plt.show()

# %%
df16.depth
# Out:
# 524     122.331500
# 532      82.135977
# 724      79.037133
# 998     150.734797
# 999     133.856500
# 1022    420.738094
# 1023    377.546406
# 2029     45.215672
# 2031     52.251270
# 2089    258.828906
# 2090    228.046500
# 2197     69.110930
# 2198     86.454828
# 2258    102.233703
# 2309     68.775477
# 2395    106.552602
# 2447     60.431109
# 2448     51.959520
# 2510     65.676641
# 2562    299.981406
# 2685    170.408906
# 2742     44.923922
# Name: depth, dtype: float64
